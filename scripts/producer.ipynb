# %%
from kafka import KafkaProducer
import json
import time
import random

producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

flights_info = {
    "FL1000": {"origin": (40.6413, -73.7781), "destination": (51.4700, -0.4543)},  # JFK -> LHR
    "FL1001": {"origin": (34.0522, -118.2437), "destination": (48.8566, 2.3522)},  # LAX -> CDG
    "FL1002": {"origin": (25.2048, 55.2708), "destination": (1.3521, 103.8198)},   # DXB -> SIN
    "FL1003": {"origin": (35.6895, 139.6917), "destination": (37.7749, -122.4194)},# Tokyo -> San Francisco
    "FL1004": {"origin": (55.7558, 37.6173), "destination": (41.9028, 12.4964)},    # Moscow -> Rome
    "FL1005": {"origin": (39.9042, 116.4074), "destination": (19.0760, 72.8777)},   # Beijing -> Mumbai
    "FL1006": {"origin": (52.5200, 13.4050), "destination": (40.7128, -74.0060)},   # Berlin -> New York
    "FL1007": {"origin": (51.5074, -0.1278), "destination": (35.6895, 139.6917)},   # London -> Tokyo
}


statuses_progression = ["On Time", "Delayed", "Boarding", "In Air", "Arrived"]

flights_state = {}
for flight_id, info in flights_info.items():
    flights_state[flight_id] = {
        "status": "On Time",
        "departure_time": int(time.time()),
        "arrival_time": int(time.time()) + random.randint(3600, 7200)
    }

while True:
    flight_id = random.choice(list(flights_info.keys()))
    state = flights_state[flight_id]

    current_status = state["status"]
    if current_status != "Arrived":
        next_status = random.choice(statuses_progression)
    else:
        next_status = "Arrived"

    state["status"] = next_status
    state["arrival_time"] += random.randint(-600, 900)  

    flight = {
        "flight_id": flight_id,
        "origin": flights_info[flight_id]["origin"],
        "destination": flights_info[flight_id]["destination"],
        "status": state["status"],
        "departure_time": state["departure_time"],
        "arrival_time": state["arrival_time"]
    }

    producer.send("flights", flight)
    print(f"Produced: {flight}")
    time.sleep(3)
# Out:
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759264327}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759263754}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759263436}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759266417}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759265635}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263333}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759265493}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759263200}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759263281}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759262734}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759265702}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263884}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263560}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759264287}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Boarding', 'departure_time': 1759259114, 'arrival_time': 1759265501}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759266141}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759263498}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759266177}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Boarding', 'departure_time': 1759259114, 'arrival_time': 1759264031}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759265557}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759263768}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759266409}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759265174}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759265243}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263864}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759266897}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759264054}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759266823}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Boarding', 'departure_time': 1759259114, 'arrival_time': 1759264121}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Boarding', 'departure_time': 1759259114, 'arrival_time': 1759266772}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759263269}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759265997}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759263749}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759263918}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759264487}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759264319}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759266570}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263943}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759266431}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263819}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759264437}
# Produced: {'flight_id': 'FL1004', 'origin': (55.7558, 37.6173), 'destination': (41.9028, 12.4964), 'status': 'Boarding', 'departure_time': 1759259114, 'arrival_time': 1759265341}
# Produced: {'flight_id': 'FL1005', 'origin': (39.9042, 116.4074), 'destination': (19.076, 72.8777), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759264246}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759263961}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759266455}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Delayed', 'departure_time': 1759259114, 'arrival_time': 1759263729}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759266277}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759263353}
# Produced: {'flight_id': 'FL1000', 'origin': (40.6413, -73.7781), 'destination': (51.47, -0.4543), 'status': 'On Time', 'departure_time': 1759259114, 'arrival_time': 1759265166}
# Produced: {'flight_id': 'FL1007', 'origin': (51.5074, -0.1278), 'destination': (35.6895, 139.6917), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759266664}
# Produced: {'flight_id': 'FL1006', 'origin': (52.52, 13.405), 'destination': (40.7128, -74.006), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759267217}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263552}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Boarding', 'departure_time': 1759259114, 'arrival_time': 1759263371}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759265729}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263474}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'In Air', 'departure_time': 1759259114, 'arrival_time': 1759263431}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759266578}
# Produced: {'flight_id': 'FL1001', 'origin': (34.0522, -118.2437), 'destination': (48.8566, 2.3522), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263589}
# Produced: {'flight_id': 'FL1003', 'origin': (35.6895, 139.6917), 'destination': (37.7749, -122.4194), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759263707}
# Produced: {'flight_id': 'FL1002', 'origin': (25.2048, 55.2708), 'destination': (1.3521, 103.8198), 'status': 'Arrived', 'departure_time': 1759259114, 'arrival_time': 1759266592}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-c1d683bbf568> in <module>
#      55     producer.send("flights", flight)
#      56     print(f"Produced: {flight}")
# ---> 57     time.sleep(3)
#      58
#
# KeyboardInterrupt:
